# %%
# !git clone https://github.com/YiLin1818/whisp.git
# Out:
# fatal: destination path 'whisp' already exists and is not an empty directory.

# %%
# %cd whisp
# Out:
# /content/whisp

# %%
# !pip install torch torchaudio --extra-index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu121
# ...

# %%
# !pip install \
  datasets[audio] \
  nemo_toolkit[tts] \
  soundfile \
  huggingface_hub \
  tiktoken \
  more-itertools \
  numba \
  tqdm \
  pydub

# %%
# !apt-get update && apt-get install -y ffmpeg
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:6 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:11 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Fetched 3,917 B in 1s (3,990 B/s)
# Reading package lists... Done
# ...

# %%
# !git checkout whisp-tts
# Out:
# Already on 'whisp-tts'
# Your branch and 'origin/whisp-tts' have diverged,
# and have 2 and 1 different commits each, respectively.
#   (use "git pull" to merge the remote branch into yours)

# %%
from audio_to_audio.pipeline import run_speech_to_speech

results = run_speech_to_speech(
    base_model="small.en",
    hf_repo="aranos/whisp",      # repo with best_model.pth
    hf_filename="best_model.pth",
    dataset_subset="commonvoice",
    dataset_split="train[:10]",  # keep small for a quick demo
    output_dir="audio_to_audio_outputs",
    target_output_dir= "audio_to_audio_target",
)

results[:3]
# Out:
# [NeMo W 2025-12-12 00:38:14 nemo_logging:405] Megatron num_microbatches_calculator not found, using Apex version.
# WARNING:nv_one_logger.api.config:OneLogger: Setting error_handling_strategy to DISABLE_QUIETLY_AND_REPORT_METRIC_ERROR for rank (rank=0) with OneLogger disabled. To override: explicitly set error_handling_strategy parameter.
# WARNING:nv_one_logger.training_telemetry.api.training_telemetry_provider:No exporters were provided. This means that no telemetry data will be collected.
# Set Whisper dims → n_mels=80, n_audio_ctx=1500, input_frames=3000
# Loading commonvoice train[:10]...
# Loading ASR-Alignment subset 'commonvoice' split 'train[:10]'...
# ...
# Resolving data files:   0%|          | 0/44 [00:00<?, ?it/s]
# Sample 0: audio shape torch.Size([89856]), words 8
#   {'start': 0.0, 'end': 0.8023, 'word': 'The'}
#   {'start': 0.8023, 'end': 1.1433, 'word': 'track'}
#   {'start': 1.1433, 'end': 1.7651, 'word': 'appears'}
#   {'start': 1.7651, 'end': 1.9255, 'word': 'on'}
# ...

# %% [markdown]
# First, we'll create a zip archive of the `audio_to_audio_outputs` and `audio_to_audio_target` directories. This command will create a file named `audio_outputs_archive.zip` in `/content/`.

# %%
# !zip -r /content/audio_outputs_archive.zip /content/whisp/audio_to_audio_outputs/ /content/whisp/audio_to_audio_target/
# Out:
#   adding: content/whisp/audio_to_audio_outputs/ (stored 0%)
#   adding: content/whisp/audio_to_audio_outputs/sample_00033.wav (deflated 12%)
#   adding: content/whisp/audio_to_audio_outputs/sample_00055.wav (deflated 18%)
#   adding: content/whisp/audio_to_audio_outputs/sample_00066.wav (deflated 15%)
#   adding: content/whisp/audio_to_audio_outputs/sample_00072.wav (deflated 15%)
#   adding: content/whisp/audio_to_audio_outputs/sample_00025.wav (deflated 14%)
#   adding: content/whisp/audio_to_audio_outputs/sample_00047.wav (deflated 13%)
#   adding: content/whisp/audio_to_audio_outputs/sample_00089.wav (deflated 20%)
#   adding: content/whisp/audio_to_audio_outputs/sample_00093.wav (deflated 13%)
#   adding: content/whisp/audio_to_audio_outputs/sample_00052.wav (deflated 15%)
#   adding: content/whisp/audio_to_audio_outputs/sample_00023.wav (deflated 14%)
#   adding: content/whisp/audio_to_audio_outputs/sample_00018.wav (deflated 16%)
# ...

# %%
from google.colab import files
files.download('/content/audio_outputs_archive.zip')
